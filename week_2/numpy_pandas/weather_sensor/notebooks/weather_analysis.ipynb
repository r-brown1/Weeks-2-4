# %%
import numpy as np
import pandas as pd

temp_data_untitled = np.random.uniform(low=32, high=55, size=(7*24, 1))
temp_data_titled = np.array(temp_data_untitled, dtype=[('NYC', 'i4'), ('Los Angeles', 'i4'), ('Chicago', 'i4')])
# print(temp_data_titled.dtype.names)
# print(temp_data_titled)

# %%
reshaped = np.reshape(temp_data_titled, (7, 24, 1))
print(reshaped)
reshaped.shape
# Out:
# [[[(42, 42, 42)]
#   [(34, 34, 34)]
#   [(48, 48, 48)]
#   [(51, 51, 51)]
#   [(51, 51, 51)]
#   [(43, 43, 43)]
#   [(40, 40, 40)]
#   [(54, 54, 54)]
#   [(32, 32, 32)]
#   [(38, 38, 38)]
#   [(45, 45, 45)]
#   [(33, 33, 33)]
#   [(40, 40, 40)]
#   [(42, 42, 42)]
#   [(39, 39, 39)]
#   [(53, 53, 53)]
#   [(44, 44, 44)]
#   [(43, 43, 43)]
#   [(42, 42, 42)]
#   [(40, 40, 40)]
#   [(52, 52, 52)]
#   [(49, 49, 49)]
#   [(34, 34, 34)]
#   [(33, 33, 33)]]
#
#  [[(51, 51, 51)]
#   [(34, 34, 34)]
#   [(35, 35, 35)]
#   [(33, 33, 33)]
#   [(36, 36, 36)]
#   [(32, 32, 32)]
#   [(32, 32, 32)]
#   [(54, 54, 54)]
#   [(37, 37, 37)]
#   [(52, 52, 52)]
#   [(32, 32, 32)]
#   [(35, 35, 35)]
#   [(39, 39, 39)]
#   [(42, 42, 42)]
#   [(53, 53, 53)]
#   [(47, 47, 47)]
#   [(44, 44, 44)]
#   [(41, 41, 41)]
#   [(45, 45, 45)]
#   [(44, 44, 44)]
#   [(44, 44, 44)]
#   [(49, 49, 49)]
#   [(36, 36, 36)]
#   [(38, 38, 38)]]
#
#  [[(36, 36, 36)]
#   [(38, 38, 38)]
#   [(35, 35, 35)]
#   [(44, 44, 44)]
# ...

# %%
df = pd.DataFrame(reshaped, columns=['NYC', 'Los Angeles', "Chicago"])
print(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 df = pd.DataFrame(reshaped, columns=['NYC', 'Los Angeles'])
#       2 print(df)
#
# File ~\OneDrive\Desktop\Week-1\.venv\Lib\site-packages\pandas\core\frame.py:805, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     802 if data.dtype.names:
#     803     # i.e. numpy structured array
#     804     data = cast(np.ndarray, data)
# --> 805     mgr = rec_array_to_mgr(
#     806         data,
#     807         index,
#     808         columns,
#     809         dtype,
#     810         copy,
#     811         typ=manager,
#     812     )
#     813 elif getattr(data, "name", None) is not None:
#     814     # i.e. Series/Index with non-None name
#     815     _copy = copy if using_copy_on_write() else True
#
# ...
